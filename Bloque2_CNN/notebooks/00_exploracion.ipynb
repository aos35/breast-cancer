# %% [markdown]
# ## **EXPLORACIÓN DEL DATASET DMID_PNG**
#
# Este notebook tiene como objetivo realizar un análisis exploratorio del dataset DMID_PNG (Digital Mammography Dataset for Breast Cancer Diagnosis Research), con el fin de comprender su estructura, calidad y distribución antes de su uso en modelos de deep learning.
#
# En esta fase se lleva a cabo la carga del dataset y la inspección de sus principales componentes: imágenes mamográficas en formato TIFF, máscaras binarias asociadas y anotaciones a nivel de píxel (PLA). Además, se realiza una visualización representativa de ejemplos del conjunto de datos para entender la correspondencia entre imágenes y sus etiquetas. También se incluye un análisis estadístico básico, donde se estudian aspectos como el rango de valores de los píxeles, la distribución de intensidades y la cobertura de las anotaciones. Este análisis permite evaluar la calidad del dataset y detectar posibles problemas como desbalance o ruido en las etiquetas.
#
# Finalmente, se generan diferentes visualizaciones (histogramas, distribuciones y grids de imágenes) que facilitan la interpretación del conjunto de datos y proporcionan una base sólida para las siguientes fases del proyecto, como el preprocesamiento y el entrenamiento de modelos de redes neuronales convolucionales.

# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import pandas as pd
import matplotlib.pyplot as plt
import re 
import random
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# ### **CARGA DEL DATASET**

# %%
BASE = Path("..") / "DMID_PNG"   # ajusta si hace falta
print("Dataset path:", BASE.resolve())
# Out:
# Dataset path: C:\Users\Usuario\Desktop\TERCERO CARRERA\2º CUATRI\Redes Neuronales\trabajo\breast-cancer\Bloque2_CNN\DMID_PNG

# %%
BASE_1024 = Path("..") / "DMID_PNG" / "1024"

all_files = list(BASE_1024.rglob("*"))

print("USANDO SOLO 1024 (alta resolución)")
print("TOTAL ARCHIVOS:", len(all_files))

print("\nESTRUCTURA 1024 (PRIMERAS DIEZ IMGAENES):")
for f in all_files[:10]:
    print("➡", f)
# Out:
# USANDO SOLO 1024 (alta resolución)
# TOTAL ARCHIVOS: 1052
#
# ESTRUCTURA 1024 (PRIMERAS DIEZ IMGAENES):
# ➡ ..\DMID_PNG\1024\Masks
# ➡ ..\DMID_PNG\1024\PLA
# ➡ ..\DMID_PNG\1024\TIFF
# ➡ ..\DMID_PNG\1024\Masks\IMG001.png
# ➡ ..\DMID_PNG\1024\Masks\IMG008.png
# ➡ ..\DMID_PNG\1024\Masks\IMG010.png
# ➡ ..\DMID_PNG\1024\Masks\IMG011.png
# ➡ ..\DMID_PNG\1024\Masks\IMG012.png
# ➡ ..\DMID_PNG\1024\Masks\IMG014.png
# ➡ ..\DMID_PNG\1024\Masks\IMG015.png

# %%
imgs = imgs = [p for p in all_files if p.is_file() and p.suffix.lower() in [".png", ".tif", ".tiff"]]
masks = masks = [p for p in all_files if p.is_file() and "mask" in str(p).lower()]
plas = plas = [p for p in all_files if p.is_file() and "pla" in str(p).lower()]

print("\nRESUMEN 1024:")
print("----------------------------------")
print("Imágenes:", len(imgs))
print("Masks:", len(masks))
print("PLA:", len(plas))
print("----------------------------------")

# gráfico visual
plt.figure(figsize=(6,6))
plt.pie(
    [len(imgs), len(masks), len(plas)],
    labels=["Imágenes (1024)", "Masks (1024)", "PLA (1024)"],
    autopct="%1.1f%%",
    startangle=90
)
plt.title("Dataset DMID - 1024")
plt.show()
# Out:
# RESUMEN 1024:
# ----------------------------------
# Imágenes: 1049
# Masks: 269
# PLA: 269
# ----------------------------------

# %%
meta_path = BASE / "Metadata.xlsx"
raw = pd.read_excel(meta_path, header=None)

df = raw.copy()

df.columns = [
    "image_id",
    "view",
    "tissue",
    "abnormality_type",
    "class",
    "x",
    "y",
    "radius"
]

# solo filas reales
df = df[df["image_id"].astype(str).str.contains("IMG", na=False)].copy()

# limpiar espacios
df["class"] = df["class"].fillna("N").astype(str).str.strip()
df.head(50)
# Out:
#    image_id    view tissue abnormality_type class       x       y radius
# 31  IMG001   MLOLT       G        MISC+CALC     M  1567.0  3644.0    295
# 32  IMG001   MLOLT       G             CIRC     B  1461.0  3102.0     85
# 33  IMG002   MLORT       G             NORM     N     NaN     NaN    NaN
# 34  IMG003    CCLT       F             NORM     N     NaN     NaN    NaN
# 35  IMG004    CCRT       F             NORM     N     NaN     NaN    NaN
# 36  IMG005    MLOLT      F             NORM     N     NaN     NaN    NaN
# 37  IMG006   MLORT       F             NORM     N     NaN     NaN    NaN
# 38  IMG007     CCLT      G             NORM     N     NaN     NaN    NaN
# 39   IMG008    CCRT      G             CIRC     B  3211.0  3904.0    216
# 40  IMG009    MLOLT      G             NORM     N     NaN     NaN    NaN
# 41   IMG010   MLORT      G             CIRC     B  3747.0  4647.0    215
# 42   IMG011   MLORT      G             CIRC     B  3222.0  2557.0    172
# 43   IMG011   MLORT      G             CIRC     B  3242.0  3802.0    258
# 44   IMG012    CCRT      G             CIRC     B  3356.0  3002.0    306
# 45   IMG012    CCRT      G             CIRC     B  3936.0  2272.0    157
# 46  IMG013    MLOLT      G             NORM     N     NaN     NaN    NaN
# 47  IMG014    MLORT      G             SPIC     M  3377.0  2569.0    287
# 48  IMG015     CCRT      G             SPIC     M  4196.0  2564.0    312
# 49  IMG016     CCLT      G             NORM     N     NaN     NaN    NaN
# 50  IMG017    MLOLT      G             NORM     N     NaN     NaN    NaN
# 51   IMG018    CCLT      G             CIRC     N  1087.0  2586.0    728
# 52   IMG019    CCLT      G             MISC     N  1782.0  2950.0    198
# 53   IMG020   MLOLT      G             CIRC     N  1169.0  3444.0    664
# 54   IMG021   MLOLT      G             CIRC     B  1797.0  3348.0    199
# 55   IMG022    CCLT      G             MISC     M  1285.0  2529.0    437
# 56   IMG023   MLOLT      G             MISC     M  1370.0  3244.0    412
# 57   IMG024    CCRT      G        SPIC+ARCH     M  4419.0  2624.0    136
# 58   IMG024    CCRT      G             CALC     B  4516.0  1918.0    447
# 59   IMG025   MLORT     G         SPIC+ARCH     M  4308.0  2799.0    118
# 60   IMG025   MLORT     G              CALC     B  4434.0  2461.0    360
# 61   IMG026    CCRT      G             CIRC     B  3850.0  4049.0    283
# 62   IMG027   MLORT      G             CIRC     B  4242.0  4789.0    315
# 63   IMG028   MLORT      F             CALC     N  2037.0  3595.0    555
# 64   IMG028   MLORT      F             CALC     N  2940.0  4487.0    226
# 65   IMG029    CCRT      F             CALC     B  2856.0  1512.0    378
# 66   IMG029    CCRT      F             CALC     B  2811.0  2035.0     90
# 67   IMG029    CCRT      F             CALC     B  2557.0  3861.0    242
# 68   IMG030    CCLT      G             MISC     M   448.0  2320.0    572
# 69   IMG030    CCLT      G             MISC     M  1234.0  2907.0    575
# 70  IMG031    CCRT       G             CIRC     B  3917.0  3712.0    226
# 71  IMG032   MLORT       G             CIRC     B  3930.0  3796.0    199
# 72  IMG033   MLORT      G        CIRC+SPIC      M  4102.0  3276.0    255
# 73  IMG034    CCRT       G       CIRC+SPIC      M  3855.0  2791.0    301
# 74  IMG035    CCRT       G             NORM     N     NaN     NaN    NaN
# 75  IMG036   MLORT       G             NORM     N     NaN     NaN    NaN
# 76  IMG037   MLOLT       G             MISC     N  2138.0  3234.0    371
# 77  IMG038    CCLT       G             MISC     N  1518.0  2799.0    327
# 78  IMG039    CCLT       G             CIRC     B   516.0  2946.0    135
# 79  IMG040   MLOLT       G             MISC     N  1192.0  3340.0    257
# 80  IMG041   MLORT       G             CIRC     B  3345.0  3020.0    124

# %%
class_counts = df["class"].value_counts()

plt.figure(figsize=(6,6))

plt.pie(
    class_counts,
    labels=class_counts.index,
    autopct="%1.1f%%",
    startangle=90
)

plt.title("Distribución real de clases (1024)")
plt.show()

# %%
def imread(p):
    try:
        return np.array(Image.open(p))
    except:
        return None

# %% [markdown]
# ### **EMPAREJAR IMÁGENES**

# %%
def extract_id(path):
    """
    Extrae ID tipo IMG001 desde el nombre del archivo
    """
    match = re.search(r'(img\d+)', path.stem.lower())
    return match.group(1) if match else None

# %%
img_dict = {}
mask_dict = {}
pla_dict = {}

# TIFF (base)
for p in imgs:
    k = extract_id(p)
    if k:
        img_dict[k] = p

# MASK
for p in masks:
    k = extract_id(p)
    if k:
        mask_dict[k] = p

# PLA
for p in plas:
    k = extract_id(p)
    if k:
        pla_dict[k] = p

print("- INDEXACIÓN COMPLETADA")
print("----------------------------------")
print(f"  - Imágenes: {len(img_dict)}")
print(f"  - Masks: {len(mask_dict)}")
print(f"  - PLA: {len(pla_dict)}")
# Out:
# - INDEXACIÓN COMPLETADA
# ----------------------------------
#   - Imágenes: 510
#   - Masks: 269
#   - PLA: 269

# %%
pairs = []
missing_mask = []
missing_pla = []

for k in img_dict.keys():
    img = img_dict.get(k)
    mask = mask_dict.get(k)
    pla = pla_dict.get(k)
    
    if mask and pla:
        pairs.append({
            "id": k,
            "image": img,
            "mask": mask,
            "pla": pla
        })
    else:
        if not mask:
            missing_mask.append(k)
        if not pla:
            missing_pla.append(k)

print("\nEMPAREJAMIENTO FINAL")
print("----------------------------------")
print(f"  - Casos completos (img+mask+pla): {len(pairs)}")
print(f"  - Sin máscara: {len(missing_mask)}")
print(f"  - Sin PLA: {len(missing_pla)}")
# Out:
# EMPAREJAMIENTO FINAL
# ----------------------------------
#   - Casos completos (img+mask+pla): 269
#   - Sin máscara: 241
#   - Sin PLA: 241

# %%
print("\nEjemplos sin mask:", missing_mask[:5])
print("Ejemplos sin PLA:", missing_pla[:5])
# Out:
# Ejemplos sin mask: ['img002', 'img003', 'img004', 'img005', 'img006']
# Ejemplos sin PLA: ['img002', 'img003', 'img004', 'img005', 'img006']

# %%
def show_case(p):
    img = np.array(Image.open(p["image"]))
    mask = np.array(Image.open(p["mask"]))
    pla = np.array(Image.open(p["pla"]))

    fig, ax = plt.subplots(1, 4, figsize=(16,4))

    # Imagen original
    ax[0].imshow(img, cmap="gray")
    ax[0].set_title("Imagen")
    ax[0].axis("off")

    # Mask
    ax[1].imshow(mask, cmap="gray")
    ax[1].set_title("Mask")
    ax[1].axis("off")

    # PLA
    ax[2].imshow(pla, cmap="gray")
    ax[2].set_title("PLA")
    ax[2].axis("off")

    # Overlay (MUY IMPORTANTE 🔥)
    ax[3].imshow(img, cmap="gray")
    ax[3].imshow(mask, cmap="jet", alpha=0.4)
    ax[3].set_title("Overlay Mask")
    ax[3].axis("off")

    plt.suptitle(f"Caso: {p['id']}", fontsize=14)
    plt.tight_layout()
    plt.show()

# %%
print("VISUALIZACIÓN DE CASOS EMPAREJADOS")
print("--------------------------------------------------")

samples = random.sample(pairs, min(5, len(pairs)))

for p in samples:
    show_case(p)
# Out:
# VISUALIZACIÓN DE CASOS EMPAREJADOS
# --------------------------------------------------

# %% [markdown]
# ### **ESTADÍSTICAS BÁSICAS**

# %%
pixel_values = []

for p in pairs:
    img = np.array(Image.open(p["image"]))
    pixel_values.append(img.flatten())

pixel_values = np.concatenate(pixel_values)

print("- ESTADÍSTICAS DE INTENSIDAD")
print("----------------------------------")
print(f"  - Min: {pixel_values.min()}")
print(f"  - Max: {pixel_values.max()}")
print(f"  - Mean: {pixel_values.mean():.2f}")
print(f"  - Std: {pixel_values.std():.2f}")
# Out:
# - ESTADÍSTICAS DE INTENSIDAD
# ----------------------------------
#   - Min: 0
#   - Max: 255
#   - Mean: 89.43
#   - Std: 107.02

# %%
plt.figure(figsize=(8,5))
plt.hist(pixel_values, bins=256)
plt.title("Distribución de intensidades de píxeles")
plt.xlabel("Intensidad")
plt.ylabel("Frecuencia")
plt.show()

# %%
# CUANTO OCUPA LA LESIÓN EN LA IMAGEN
coverages = []

for p in pairs:
    mask = np.array(Image.open(p["mask"]))
    
    # binarizar por si acaso
    mask = (mask > 0).astype(np.uint8)
    
    coverage = mask.mean()   # % de píxeles con lesión
    coverages.append(coverage)

coverages = np.array(coverages)

print("- COBERTURA DE LESIONES")
print("----------------------------------")
print(f"  - Media: {coverages.mean()*100:.2f}%")
print(f"  - Min: {coverages.min()*100:.2f}%")
print(f"  - Max: {coverages.max()*100:.2f}%")
# Out:
# - COBERTURA DE LESIONES
# ----------------------------------
#   - Media: 26.30%
#   - Min: 0.20%
#   - Max: 53.18%

# %%
plt.figure(figsize=(8,5))
plt.hist(coverages * 100, bins=30)
plt.title("Distribución de cobertura de lesiones (%)")
plt.xlabel("% de imagen ocupada")
plt.ylabel("Frecuencia")
plt.show()

# %%
sizes = []

for p in pairs:
    img = np.array(Image.open(p["image"]))
    sizes.append(img.shape)

unique_sizes = set(sizes)

print("- TAMAÑOS DE IMAGEN")
print("----------------------------------")
print(unique_sizes)
# Out:
# - TAMAÑOS DE IMAGEN
# ----------------------------------
# {(1024, 1024, 3), (1024, 1024, 4), (1024, 1024)}

# %%
# índice de menor y mayor cobertura
min_idx = np.argmin(coverages)
max_idx = np.argmax(coverages)

print("- Ejemplo menor lesión:")
show_case(pairs[min_idx])

print("- Ejemplo mayor lesión:")
show_case(pairs[max_idx])
# Out:
# - Ejemplo menor lesión:
# - Ejemplo mayor lesión:
